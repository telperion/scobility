# %%
import logging

import scobility
import scobility_scrape as scrape

tourney = 'itl2025'

# %%
only_scores = False

path_dst = scrape.setup_scrape(tourney)
if not only_scores:
    scrape.scrape_charts(path_dst, tourney)
    scrape.scrape_entrants(path_dst, tourney)
scrape.scrape_scores(path_dst, tourney)

logging.info('Done!')

# %%
scobility.process(src=tourney, force_recalculate_spice=True)
