# %%
import logging

import scobility, scobility_scrape as scrape

# %%
only_scores = False

path_dst = scrape.setup_scrape()
if not only_scores:
    scrape.scrape_charts(path_dst)
    scrape.scrape_entrants(path_dst)
scrape.scrape_scores(path_dst)

logging.info('Done!')

# %%
scobility.process(src='itl2024', force_recalculate_spice=True)
